# %% [markdown]
# # Finetuning
#
# The purpose of this script is to finetune yolo to our custom drone dataset.
#
# This involves the following steps:
# - create folder structure for data
# - split train/val/test
# - finetune and visualize training
# - test

# %%
# dependencies

# !git clone https://github.com/ultralytics/yolov5  # clone repository
# !cd yolov5
# !pwd
# !pip install -r yolov5/requirements.txt  # install dependencies
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
#
#
# ⚡️ Tip	Check organization access: https://github.com/settings/connections/applications/c7457225b242a94d60c6
#
# /teamspace/studios/this_studio
# Requirement already satisfied: gitpython>=3.1.30 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 6)) (3.8.2)
# Requirement already satisfied: numpy>=1.23.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 8)) (4.9.0.80)
# Requirement already satisfied: pillow>=10.3.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 9)) (10.4.0)
# Requirement already satisfied: psutil in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 10)) (6.0.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 13)) (1.11.4)
# Requirement already satisfied: thop>=0.1.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 15)) (2.2.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 16)) (0.17.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 17)) (4.66.1)
# Requirement already satisfied: ultralytics>=8.2.34 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 18)) (8.2.91)
# Requirement already satisfied: pandas>=1.1.4 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 27)) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 42)) (72.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from gitpython>=3.1.30->-r yolov5/requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.32.0->-r yolov5/requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.32.0->-r yolov5/requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.32.0->-r yolov5/requirements.txt (line 12)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.32.0->-r yolov5/requirements.txt (line 12)) (2024.8.30)
# Requirement already satisfied: filelock in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: sympy in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.13.2)
# Requirement already satisfied: networkx in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.3)
# Requirement already satisfied: jinja2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.1.4)
# Requirement already satisfied: fsspec in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.6.68)
# Requirement already satisfied: py-cpuinfo in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics>=8.2.34->-r yolov5/requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ultralytics>=8.2.34->-r yolov5/requirements.txt (line 18)) (2.0.6)
# Requirement already satisfied: pytz>=2020.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r yolov5/requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from sympy->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.3.0)

# %%
# imports

import os
import torch

# %%
# download yolov5s model

# path to your custom model
model_path = "yolov5s.pt" 

# load custom model
model = torch.hub.load(
    "ultralytics/yolov5", 
    "custom", 
    path=model_path, 
    force_reload=True
)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/zeus/.cache/torch/hub/master.zip
# YOLOv5 🚀 2024-9-10 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# split into train/val/test images and corresponding labels from dataset/raw/ and put them into dataset/finetune/images/train, dataset/finetune/images/val, and dataset/finetune/images/test

import os
import shutil
import random
from pathlib import Path

# Define paths
raw_image_dir = Path('dataset/raw/images')
raw_label_dir = Path('dataset/raw/labels')

train_image_dir = Path('dataset/finetune/images/train')
val_image_dir = Path('dataset/finetune/images/val')
test_image_dir = Path('dataset/finetune/images/test')

train_label_dir = Path('dataset/finetune/labels/train')
val_label_dir = Path('dataset/finetune/labels/val')
test_label_dir = Path('dataset/finetune/labels/test')

# Create directories if they don't exist
for directory in [train_image_dir, val_image_dir, test_image_dir, train_label_dir, val_label_dir, test_label_dir]:
    directory.mkdir(parents=True, exist_ok=True)

# Get list of all images
image_files = list(raw_image_dir.glob('*.png'))  # Assuming images are .jpg, adjust extension if needed
random.shuffle(image_files)  # Shuffle to randomize

# Split percentages
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

# Calculate split indices
total_images = len(image_files)
train_count = int(train_ratio * total_images)
val_count = int(val_ratio * total_images)

train_files = image_files[:train_count]
val_files = image_files[train_count:train_count + val_count]
test_files = image_files[train_count + val_count:]

# Function to move files
def move_files(image_list, image_dest, label_dest):
    for image_file in image_list:
        # Corresponding label file (assumes same name but with .txt extension)
        label_file = raw_label_dir / f"{image_file.stem}.txt"

        # Move the image
        shutil.copy(image_file, image_dest / image_file.name)

        # Move the label if it exists
        if label_file.exists():
            shutil.copy(label_file, label_dest / label_file.name)

# Move the files to the respective directories
move_files(train_files, train_image_dir, train_label_dir)
move_files(val_files, val_image_dir, val_label_dir)
move_files(test_files, test_image_dir, test_label_dir)

print(f"Dataset split into {len(train_files)} train, {len(val_files)} val, and {len(test_files)} test files.")
# Out:
# Dataset split into 219 train, 27 val, and 28 test files.

# %%
# Inference on images

base_path = "dataset/finetune/images/train"

# Get all image paths
imgs_paths = [os.path.join(base_path, img) for img in os.listdir(base_path) if img.endswith(".png")]

# sample
full_paths = imgs_paths[:10]

print(full_paths)
# Out:
# ['dataset/finetune/images/train/frame000681.png', 'dataset/finetune/images/train/frame000395.png', 'dataset/finetune/images/train/frame000341.png', 'dataset/finetune/images/train/frame000987.png', 'dataset/finetune/images/train/frame000991.png', 'dataset/finetune/images/train/frame000149.png', 'dataset/finetune/images/train/frame001038.png', 'dataset/finetune/images/train/frame000676.png', 'dataset/finetune/images/train/frame000414.png', 'dataset/finetune/images/train/frame000404.png']

# %%
# inference trial before fine-tuning

for img in full_paths:
    # Run inference
    try:
        print(f"Processed image {img}")
        results = model(img)
    except Exception as e:
        print(f"Failed to process image {img}")
        print(e)

    # Display results
    print(results)
# Out:
# Processed image dataset/finetune/images/train/frame000681.png
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1: 720x1280 3 persons, 1 car, 1 chair
# Speed: 40.6ms pre-process, 73.8ms inference, 611.8ms NMS per image at shape (1, 3, 384, 640)
# Processed image dataset/finetune/images/train/frame000395.png
# image 1/1: 720x1280 5 persons
# Speed: 28.3ms pre-process, 5.7ms inference, 1.2ms NMS per image at shape (1, 3, 384, 640)
# Processed image dataset/finetune/images/train/frame000341.png
# image 1/1: 720x1280 2 persons
# Speed: 25.8ms pre-process, 5.9ms inference, 1.5ms NMS per image at shape (1, 3, 384, 640)
# Processed image dataset/finetune/images/train/frame000987.png
# image 1/1: 720x1280 1 person
# Speed: 28.1ms pre-process, 6.2ms inference, 1.4ms NMS per image at shape (1, 3, 384, 640)
# Processed image dataset/finetune/images/train/frame000991.png
# image 1/1: 720x1280 (no detections)
# Speed: 27.3ms pre-process, 8.0ms inference, 0.8ms NMS per image at shape (1, 3, 384, 640)
# Processed image dataset/finetune/images/train/frame000149.png
# image 1/1: 720x1280 3 persons
# Speed: 23.4ms pre-process, 7.5ms inference, 1.2ms NMS per image at shape (1, 3, 384, 640)
# Processed image dataset/finetune/images/train/frame001038.png
# image 1/1: 720x1280 2 persons
# Speed: 24.5ms pre-process, 5.4ms inference, 1.1ms NMS per image at shape (1, 3, 384, 640)
# Processed image dataset/finetune/images/train/frame000676.png
# image 1/1: 720x1280 4 persons, 1 chair
# Speed: 24.4ms pre-process, 5.4ms inference, 1.1ms NMS per image at shape (1, 3, 384, 640)
# Processed image dataset/finetune/images/train/frame000414.png
# image 1/1: 720x1280 9 persons
# Speed: 24.7ms pre-process, 5.4ms inference, 1.1ms NMS per image at shape (1, 3, 384, 640)
# Processed image dataset/finetune/images/train/frame000404.png
# image 1/1: 720x1280 9 persons
# Speed: 24.7ms pre-process, 5.7ms inference, 1.2ms NMS per image at shape (1, 3, 384, 640)

# %%
# finetuning

# !pip install clearml

from clearml import Task

# Set ClearML environment variables
os.environ['CLEARML_WEB_HOST'] = 'https://app.clear.ml/'
os.environ['CLEARML_API_HOST'] = 'https://api.clear.ml'
os.environ['CLEARML_FILES_HOST'] = 'https://files.clear.ml'
os.environ['CLEARML_API_ACCESS_KEY'] = 'L94OV6F8DHTZT05E87M43SCIQBV870'
os.environ['CLEARML_API_SECRET_KEY'] = '7YZ_V87ju3V1RYJ9BQvrfruCAYrvEV65D-sRHR-eC7b-TJ0bnb5F2ckq9Al-iPEUgXI'

# Initialize ClearML task for finetuning YOLO on drones
task = Task.init(project_name='YOLOv5 Drone Detection', task_name='Finetuning YOLOv5 for Drones')

# finetune
# !python yolov5/train.py --img 640 --batch 32 --epochs 150 --data yolov5/dataset.yaml --weights yolov5s.pt --cache
# Out:
# Requirement already satisfied: clearml in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (1.16.4)
# Requirement already satisfied: attrs>=18.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (24.2.0)
# Requirement already satisfied: furl>=2.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (2.1.3)
# Requirement already satisfied: jsonschema>=2.6.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (4.23.0)
# Requirement already satisfied: numpy>=1.10 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (1.26.4)
# Requirement already satisfied: pathlib2>=2.3.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (2.3.7.post1)
# Requirement already satisfied: Pillow>=4.1.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (10.4.0)
# Requirement already satisfied: psutil>=3.4.2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (6.0.0)
# Requirement already satisfied: pyparsing>=2.0.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (2.9.0.post0)
# Requirement already satisfied: PyYAML>=3.12 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (6.0.2)
# Requirement already satisfied: requests>=2.20.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (2.32.3)
# Requirement already satisfied: six>=1.13.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (1.16.0)
# Requirement already satisfied: urllib3>=1.21.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (2.2.2)
# Requirement already satisfied: pyjwt<2.9.0,>=2.4.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (2.8.0)
# Requirement already satisfied: referencing<0.40 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from clearml) (0.35.1)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from furl>=2.0.0->clearml) (1.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from jsonschema>=2.6.0->clearml) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from jsonschema>=2.6.0->clearml) (0.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.20.0->clearml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.20.0->clearml) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.20.0->clearml) (2024.8.30)
# train: weights=yolov5s.pt, cfg=, data=yolov5/dataset.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5/data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-365-g12b577c8 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /teamspace/studios/this_studio/dataset/finetune/labels/train.cac
# train: Caching images (0.1GB ram): 100%|██████████| 219/219 [00:00<00:00, 224.14
# val: Scanning /teamspace/studios/this_studio/dataset/finetune/labels/val.cache..
# val: Caching images (0.0GB ram): 100%|██████████| 27/27 [00:00<00:00, 105.21it/s
#
# AutoAnchor: 3.95 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/exp4/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to yolov5/runs/train/exp4
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/149      7.25G     0.1247    0.02863          0         49        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27   0.000123      0.037   7.33e-05   7.33e-06
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/149      7.25G     0.1118    0.02547          0         59        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27   0.000247     0.0741    0.00021   3.74e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/149      7.25G     0.1025    0.02188          0         41        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27   0.000494      0.148    0.00061    9.1e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/149      7.25G    0.09153    0.01996          0         44        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27    0.00123       0.37     0.0032    0.00065
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/149      7.25G    0.08046    0.02046          0         44        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27    0.00321      0.963     0.0726     0.0299
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/149      7.25G    0.07589    0.02062          0         56        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27    0.00321      0.963      0.226      0.057
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/149      7.25G    0.06721    0.02021          0         60        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27    0.00874      0.926      0.764      0.289
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/149      7.25G    0.06601    0.01936          0         48        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27       0.23      0.926       0.73      0.241
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/149      7.25G    0.06439    0.01816          0         43        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.765      0.482      0.721      0.163
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/149      7.25G    0.06312     0.0165          0         53        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.788       0.37      0.759      0.296
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/149      7.25G    0.06055    0.01846          0         51        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.231      0.333      0.142     0.0303
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/149      7.25G    0.06116    0.01765          0         57        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.887      0.585      0.865      0.317
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/149      7.25G     0.0581    0.01748          0         50        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.814      0.481      0.635      0.221
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/149      7.25G    0.05783     0.0166          0         50        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.734      0.704      0.834      0.282
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/149      7.25G    0.05503     0.0162          0         65        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.822      0.519      0.673      0.198
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/149      7.25G    0.05296    0.01643          0         49        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.733      0.711      0.865      0.352
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/149      7.25G    0.04832    0.01712          0         63        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.665      0.778      0.773      0.184
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/149      7.25G    0.04543    0.01662          0         58        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.962      0.963      0.961      0.407
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/149      7.25G    0.04544    0.01624          0         54        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.882      0.926      0.929      0.387
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/149      7.25G    0.04393    0.01457          0         56        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27       0.68      0.394      0.581      0.164
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/149      7.25G     0.0427     0.0145          0         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.956      0.963      0.973      0.338
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/149      7.25G    0.03976    0.01371          0         45        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27       0.92      0.926      0.949      0.341
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/149      7.25G    0.03745    0.01256          0         49        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27       0
0         43        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.993          1      0.995      0.914
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     139/149      7.25G    0.01126   0.003844          0         48        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.992          1      0.995        0.9
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     140/149      7.25G    0.01046   0.003563          0         44        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.991          1      0.995      0.909
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     141/149      7.25G       0.01   0.003629          0         48        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.991          1      0.995      0.919
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     142/149      7.25G    0.01004   0.003795          0         64        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.991          1      0.995      0.912
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     143/149      7.25G   0.009601   0.003442          0         44        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.992          1      0.995      0.914
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     144/149      7.25G    0.01068    0.00396          0         49        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.993          1      0.995      0.926
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     145/149      7.25G   0.009611    0.00349          0         37        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.993          1      0.995      0.918
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     146/149      7.25G   0.009472   0.003433          0         45        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.994          1      0.995      0.918
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     147/149      7.25G    0.01044   0.003805          0         50        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.994          1      0.995      0.923
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     148/149      7.25G    0.00964   0.003658          0         47        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.994          1      0.995      0.915
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     149/149      7.25G   0.008901   0.003263          0         43        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.994          1      0.995      0.923
#
# 150 epochs completed in 0.144 hours.
# Optimizer stripped from yolov5/runs/train/exp4/weights/last.pt, 14.3MB
# Optimizer stripped from yolov5/runs/train/exp4/weights/best.pt, 14.3MB
#
# Validating yolov5/runs/train/exp4/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         27         27      0.994          1      0.995      0.932
# Results saved to yolov5/runs/train/exp4
# 2024-09-10 21:11:36,948 - clearml.storage - INFO - Uploading: 13.68MB to yolov5/runs/train/exp4/weights/best.pt
# ██████████████████████████████▉ 100% | 13.68/13.68 MB [00:00<00:00, 62.16MB/s]:
# 2024-09-10 21:11:37,170 - clearml.Task - INFO - Completed model upload to https://files.clear.ml/YOLOv5%20Drone%20Detection/Finetuning%20YOLOv5%20for%20Drones.bc9da274eb304833b0ac12e6741a7130/models/best.pt

# %%
# test: check results on yolov5/runs/detect 

# !python yolov5/detect.py --weights yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source dataset/finetune/images/test
# Out:
# detect: weights=['yolov5/runs/train/exp/weights/best.pt'], source=dataset/finetune/images/test, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-365-g12b577c8 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000008.png: 384x640 (no detections), 46.0ms
# image 2/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000011.png: 384x640 (no detections), 5.6ms
# image 3/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000138.png: 384x640 (no detections), 5.7ms
# image 4/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000238.png: 384x640 (no detections), 5.4ms
# image 5/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000329.png: 384x640 (no detections), 8.4ms
# image 6/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000337.png: 384x640 (no detections), 5.5ms
# image 7/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000343.png: 384x640 (no detections), 8.7ms
# image 8/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000377.png: 384x640 1 drone, 5.6ms
# image 9/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000384.png: 384x640 1 drone, 6.9ms
# image 10/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000401.png: 384x640 2 drones, 5.4ms
# image 11/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000431.png: 384x640 (no detections), 5.5ms
# image 12/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000433.png: 384x640 (no detections), 5.8ms
# image 13/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000458.png: 384x640 (no detections), 5.3ms
# image 14/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000469.png: 384x640 (no detections), 5.6ms
# image 15/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000489.png: 384x640 (no detections), 5.5ms
# image 16/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000634.png: 384x640 (no detections), 5.6ms
# image 17/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000680.png: 384x640 (no detections), 5.7ms
# image 18/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000685.png: 384x640 (no detections), 5.5ms
# image 19/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000695.png: 384x640 (no detections), 5.6ms
# image 20/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000970.png: 384x640 (no detections), 5.6ms
# image 21/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000974.png: 384x640 1 drone, 5.6ms
# image 22/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000979.png: 384x640 1 drone, 7.1ms
# image 23/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000984.png: 384x640 1 drone, 5.4ms
# image 24/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame000995.png: 384x640 (no detections), 8.2ms
# image 25/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame001004.png: 384x640 (no detections), 5.5ms
# image 26/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame001043.png: 384x640 (no detections), 5.4ms
# image 27/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame001045.png: 384x640 (no detections), 5.5ms
# image 28/28 /teamspace/studios/this_studio/dataset/finetune/images/test/frame001052.png: 384x640 (no detections), 5.5ms
# Speed: 0.5ms pre-process, 7.4ms inference, 19.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp
